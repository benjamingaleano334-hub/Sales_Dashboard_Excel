# %% [markdown]
# # **Proyecto: Dashboard de Ventas y Ganancias**
# Este notebook acompaña al análisis realizado en Excel.
# Incluye descripción del dataset, explicación de KPIs y conclusiones del proyecto.
#
# -------
#
# ## **Dataset**
# El archivo `sales_data.xlsx` contiene las columnas:
# - **Date**
# - **Day**
# - **Month**
# - **Customer_age**
# - **Age_group**
# - **Customer_gender**
# - **Country**
# - **State**
# - **Product_category**
# - **Sub_category**
# - **Product**
# - **Order_quantity**
# - **Unit_cost**
# - **Unit_price**
# - **Profit**
# - **Cost**
# - **Revenue**

# %% [markdown]
# -----
# ## **📈 Dashboard en Excel**
# El Dashboard incluye los siguientes **KPIs**:
# - **Ingresos Totales:** $84,826,772
# - **Ganancia Neta:** $32,046,239
# - **Producto más vendido:** *Water Bottle – 30 oz*
# - **Cantidad total de órdenes:** 162,051
#
# -----
#
# ### **Visualizaciones**
# - **Ventas por categoría:** gráfico de anillo que muestra la distribución entre *Accessories, Bikes y Clothing*.
# - **Ventas por grupo de edad:** barras horizontales que comparan *Youth, Young Adults, Adults y Seniors*.
# - **Ingresos netos por país:** gráfico de barras verticales con *Australia, Canadá, Francia, Alemania, Reino Unido y Estados Unidos*.
# - **Tendencia temporal de ingresos:** gráfico de líneas que muestra la evolución entre 2011 y 2016, con un crecimiento marcado hasta 2015.

# %% [markdown]
# ## Dashboard en Excel
# ![Dashboard de Ventas](dashboard_excell.png)

# %% [markdown]
# ## **✅ Conclusiones**
# - El **producto más vendido** es la botella de agua de 30 oz, lo que refleja alta demanda en accesorios.
# - El **grupo de edad adulto (35–64)** concentra la mayor parte de las ventas.
# - El **mercado más rentable** es Estados Unidos, seguido por Alemania y Reino Unido.
# - La **tendencia temporal de ingresos** muestra un crecimiento sostenido, con un pico en 2015.
